# %% [markdown]
# <a href="https://colab.research.google.com/github/sunshineluyao/waiting-time-eip1559/blob/main/code/Data_Query/Query_Data_EthereumETL_Public.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# references:
#
# https://github.com/blockchain-etl/ethereum-etl
#
# https://github.com/Rising-Stars-by-Sunshine/EthereumETL-Instructions/blob/main/Problem_Set_1_Demo_Ethereum_Blockchain_API.ipynb
#
# https://github.com/sunshineluyao/waiting-time-eip1559/blob/main/code/Data_Query/Query_Data_MemopoolGuru_Public.ipynb

# %% [markdown]
# # Part I: Set up

# %%
# install ethereum-etl and pandas
# !python -m pip install ethereum-etl pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ethereum-etl
#   Downloading ethereum-etl-2.1.2.tar.gz (336 kB)
#      |████████████████████████████████| 336 kB 6.9 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (1.3.5)
# Collecting web3<6,>=5.29
#   Downloading web3-5.31.3-py3-none-any.whl (501 kB)
#      |████████████████████████████████| 501 kB 43.5 MB/s
# Collecting eth-utils==1.10
#   Downloading eth_utils-1.10.0-py3-none-any.whl (24 kB)
# Collecting eth-abi<3.0.0,>=2.2.0
#   Downloading eth_abi-2.2.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.8/dist-packages (from ethereum-etl) (2.8.2)
# Collecting click==8.0.4
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 3.4 MB/s
# Collecting ethereum-dasm==0.1.4
#   Downloading ethereum_dasm-0.1.4-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 939 kB/s
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from ethereum-etl) (2.23.0)
# Collecting cytoolz<1.0.0,>=0.10.1
#   Downloading cytoolz-0.12.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 24.7 MB/s
# Collecting eth-typing<3.0.0,>=2.2.1
#   Downloading eth_typing-2.3.0-py3-none-any.whl (6.2 kB)
# Collecting eth-hash<0.4.0,>=0.3.1
#   Downloading eth_hash-0.3.3-py3-none-any.whl (8.9 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting evmdasm
#   Downloading evmdasm-0.1.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from ethereum-dasm==0.1.4->ethereum-etl) (0.8.10)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from cytoolz<1.0.0,>=0.10.1->eth-utils==1.10->ethereum-etl) (0.12.0)
# Collecting parsimonious<0.9.0,>=0.8.0
#   Downloading parsimonious-0.8.1.tar.gz (45 kB)
#      |████████████████████████████████| 45 kB 1.6 MB/s
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from parsimonious<0.9.0,>=0.8.0->eth-abi<3.0.0,>=2.2.0->ethereum-etl) (1.15.0)
# Collecting eth-rlp<0.3
#   Downloading eth_rlp-0.2.1-py3-none-any.whl (5.0 kB)
# Collecting ipfshttpclient==0.8.0a2
#   Downloading ipfshttpclient-0.8.0a2-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 355 kB/s
# Collecting protobuf==3.19.5
#   Downloading protobuf-3.19.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 61.1 MB/s
# Collecting websockets<10,>=9.1
#   Downloading websockets-9.1-cp38-cp38-manylinux2010_x86_64.whl (102 kB)
#      |████████████████████████████████| 102 kB 5.8 MB/s
# Collecting eth-account<0.6.0,>=0.5.9
#   Downloading eth_account-0.5.9-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 6.8 MB/s
# Collecting lru-dict<2.0.0,>=1.1.6
#   Downloading lru_dict-1.1.8-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting eth-hash[pycryptodome]<1.0.0,>=0.2.0
#   Downloading eth_hash-0.5.1-py3-none-any.whl (9.0 kB)
# Collecting hexbytes<1.0.0,>=0.1.0
#   Downloading hexbytes-0.3.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: aiohttp<4,>=3.7.4.post0 in /usr/local/lib/python3.8/dist-packages (from web3<6,>=5.29->ethereum-etl) (3.8.3)
# Requirement already satisfied: jsonschema<5,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from web3<6,>=5.29->ethereum-etl) (4.3.3)
# Collecting multiaddr>=0.0.7
#   Downloading multiaddr-0.0.9-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4,>=3.7.4.post0->web3<6,>=5.29->ethereum-etl) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4,>=3.7.4.post0->web3<6,>=5.29->ethereum-etl) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4,>=3.7.4.post0->web3<6,>=5.29->ethereum-etl) (6.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4,>=3.7.4.post0->web3<6,>=5.29->ethereum-etl) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4,>=3.7.4.post0->web3<6,>=5.29->ethereum-etl) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4,>=3.7.4.post0->web3<6,>=5.29->ethereum-etl) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp<4,>=3.7.4.post0->web3<6,>=5.29->ethereum-etl) (1.3.1)
# Collecting bitarray<3,>=1.2.1
#   Downloading bitarray-2.6.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
#      |████████████████████████████████| 241 kB 88.4 MB/s
# Collecting rlp<3,>=1.0.0
#   Downloading rlp-2.0.1-py2.py3-none-any.whl (20 kB)
# Collecting eth-keyfile<0.6.0,>=0.5.0
#   Downloading eth_keyfile-0.5.1-py3-none-any.whl (8.3 kB)
# Collecting eth-keys<0.4.0,>=0.3.4
#   Downloading eth_keys-0.3.4-py3-none-any.whl (21 kB)
# Collecting eth-hash[pycryptodome]<1.0.0,>=0.2.0
#   Downloading eth_hash-0.5.0-py3-none-any.whl (8.9 kB)
#   Downloading eth_hash-0.4.0-py3-none-any.whl (9.0 kB)
# Collecting pycryptodome<4,>=3.6.6
#   Downloading pycryptodome-3.16.0-cp35-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 44.1 MB/s
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema<5,>=3.2.0->web3<6,>=5.29->ethereum-etl) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema<5,>=3.2.0->web3<6,>=5.29->ethereum-etl) (5.10.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema<5,>=3.2.0->web3<6,>=5.29->ethereum-etl) (3.11.0)
# Collecting netaddr
#   Downloading netaddr-0.8.0-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 28.2 MB/s
# Collecting varint
#   Downloading varint-1.0.2.tar.gz (1.9 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->ethereum-etl) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->ethereum-etl) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->ethereum-etl) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->ethereum-etl) (1.24.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas) (1.21.6)
# Building wheels for collected packages: ethereum-etl, parsimonious, varint
#   Building wheel for ethereum-etl (setup.py) ... done
#   Created wheel for ethereum-etl: filename=ethereum_etl-2.1.2-py3-none-any.whl size=438787 sha256=fd2a7f9fa374cc53a3199d1c9070d0925a0b6601e41bae405b71810047b3cbec
#   Stored in directory: /root/.cache/pip/wheels/86/fb/f7/651b3dfbc02c9a3cbe1cffe2589a5be8f929c606002fa74943
#   Building wheel for parsimonious (setup.py) ... done
#   Created wheel for parsimonious: filename=parsimonious-0.8.1-py3-none-any.whl size=42725 sha256=d94e73be77032e6d4ad5974457a5f5f89bd9107377df97829e170a04be86bf80
#   Stored in directory: /root/.cache/pip/wheels/d8/af/19/fb896f509a437aca2dcf62583e84d7fb2cd5b628c1564a609c
#   Building wheel for varint (setup.py) ... done
#   Created wheel for varint: filename=varint-1.0.2-py3-none-any.whl size=1978 sha256=75c62e41edb28bae925829c4235ec47f976bc3cbe1a53a465e07aaeed617015d
#   Stored in directory: /root/.cache/pip/wheels/cc/a8/a4/4d9e9807c27585dc974fc0e86a3e4345649d71f8a35906d1a8
# Successfully built ethereum-etl parsimonious varint
# Installing collected packages: eth-typing, eth-hash, cytoolz, eth-utils, varint, rlp, pycryptodome, parsimonious, netaddr, hexbytes, eth-keys, base58, multiaddr, eth-rlp, eth-keyfile, eth-abi, bitarray, websockets, protobuf, lru-dict, ipfshttpclient, evmdasm, eth-account, colorama, web3, ethereum-dasm, click, ethereum-etl
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.0.4 which is incompatible.
# Successfully installed base58-2.1.1 bitarray-2.6.0 click-8.0.4 colorama-0.4.6 cytoolz-0.12.0 eth-abi-2.2.0 eth-account-0.5.9 eth-hash-0.3.3 eth-keyfile-0.5.1 eth-keys-0.3.4 eth-rlp-0.2.1 eth-typing-2.3.0 eth-utils-1.10.0 ethereum-dasm-0.1.4 ethereum-etl-2.1.2 evmdasm-0.1.10 hexbytes-0.3.0 ipfshttpclient-0.8.0a2 lru-dict-1.1.8 multiaddr-0.0.9 netaddr-0.8.0 parsimonious-0.8.1 protobuf-3.19.5 pycryptodome-3.16.0 rlp-2.0.1 varint-1.0.2 web3-5.31.3 websockets-9.1

# %%
# mount google drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# print the current directory
# !pwd
# Out:
# /content

# %%
#@title path
#create a project folder and identify the path
path = "/content/drive/MyDrive/waitingtime" #@param {type:"string"}

# %%
#go to your project folder 
# %cd /content/drive/MyDrive/waitingtime
# Out:
# /content/drive/MyDrive/waitingtime

# %%
# print the current directory again to make sure that you are in the project folder
# !pwd
# Out:
# /content/drive/MyDrive/waitingtime

# %% [markdown]
# # Part II: Query Data and Export CSV

# %%
# import libraries to print data frame
import pandas as pd
# set to print the maximum numbers of rows
pd.set_option('display.max_rows', None)

# %%
#@title import using QuickNode
QuickNode_end_points_URL = "https://indulgent-cold-energy.discover.quiknode.pro/API_KEY" #@param {type:"string"}

# %% [markdown]
# ## 2.1. Query Block Data before and After the Merge

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15467393 --end-block 15607393 --blocks-output blocks_merge.csv --provider-uri https://indulgent-cold-energy.discover.quiknode.pro/API_KEY
# Out:
# Streaming output truncated to the last 5000 lines.
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:03,769 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:03,771 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:03,848 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:05,313 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:05,316 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:05,320 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:05,320 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:05,322 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:05,323 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:05,323 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:05,325 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:05,335 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:05,336 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:05,336 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:05,336 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:05,341 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:05,341 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:05,345 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:05,346 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:05,357 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:05,357 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:05,357 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:05,346 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:06,895 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:06,895 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:06,905 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:06,905 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:06,908 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:06,909 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:06,909 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:06,909 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:06,912 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:06,913 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:06,915 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:06,916 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:06,926 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:06,926 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:06,932 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:06,933 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:06,934 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:06,934 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:06,968 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:06,969 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:08,535 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:08,535 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:08,542 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:08,542 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:08,545 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:08,545 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:08,547 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:08,547 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:08,549 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:08,550 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:08,554 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:08,554 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:08,561 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
# ...
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:40,210 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:40,207 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:40,234 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:40,235 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:40,238 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:40,237 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:40,237 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:40,237 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:40,236 - BatchWorkExecutor [ERROR] - An exception occurred while executing work_handler.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:40,238 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:40,240 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:40,240 - BatchWorkExecutor [INFO] - The batch of size 1 will be retried one item at a time.
# 2022-12-12 17:08:40,257 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:40,258 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:40,258 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:40,259 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 2022-12-12 17:08:40,260 - root [ERROR] - An exception occurred while executing execute_with_retries. Retry #0
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 63, in _fail_safe_execute
#     work_handler(batch)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/jobs/export_blocks_job.py", line 75, in _export_batch
#     response = self.batch_web3_provider.make_batch_request(json.dumps(blocks_rpc))
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# 2022-12-12 17:08:40,285 - root [INFO] - The request will be retried after 1 seconds. Retry #0
# 
# 6  0x3ecef08d0e2dad803847e052249bb4f8bff2d5bb  12408692301453270
# 7  0x829bd824b016326a401d083b33d092293333a830  12415052033747179
# 8  0x829bd824b016326a401d083b33d092293333a830  12632969426213882
# 9  0x00192fb10df37c9fb26829eb2cc623cd1bf599e8  12396849315784578
#
#           total_difficulty    size  \
# 0  57892675451653990037725   35021
# 1  57893927202988749503803   47208
# 2  57892688071749348564159    6705
# 3  57896399876958192707976  139953
# 4  57893939623830769611668   65678
# 5  57892700704443896871097   38746
# 6  57896412285650494161246  136493
# 7  57893952038882803358847   39772
# 8  57892713337413323084979  107454
# 9  57896424682499809945824  137741
#
#                                           extra_data  gas_limit  gas_used  \
# 0             0xe4b883e5bda9e7a59ee4bb99e9b1bc280721   30000000   7599434
# 1                       0x617369612d65617374322d3131   29999972  12111413
# 2                                   0x657a696c2e6d65   30000000   1674394
# 3                       0x617369612d65617374322d3134   30029295  30010865
# 4  0x466c6578706f6f6c2f53302f484b202d204d656c626f...   30000000  15036069
# 5           0x486976656f6e2072752d68656176792d696b70   30000000  29994370
# 6                                         0x73656f36   30000000  29983658
# 7             0xe4b883e5bda9e7a59ee4bb99e9b1bc050921   30000000  10314110
# 8             0xe4b883e5bda9e7a59ee4bb99e9b1bc4b3121   30000000  29998655
# 9  0x457468657265756d50504c4e532f326d696e6572735f...   30000000  29983936
#
#     timestamp  transaction_count  base_fee_per_gas
# 0  1662237222                 52        9787352044
# 1  1662238920                156        9563105534
# 2  1662237229                 20        9183752505
# 3  1662241702                945        2970262901
# 4  1662238935                151        9332907583
# 5  1662237231                150        8163926943
# 6  1662241705                233        3341090050
# 7  1662238956                 82        9335712821
# 8  1662237247                289        9184034786
# 9  1662241737                310        3758271305

# %%
merge_blocks.columns
# Out:
# Index(['number', 'hash', 'parent_hash', 'nonce', 'sha3_uncles', 'logs_bloom',
#        'transactions_root', 'state_root', 'receipts_root', 'miner',
#        'difficulty', 'total_difficulty', 'size', 'extra_data', 'gas_limit',
#        'gas_used', 'timestamp', 'transaction_count', 'base_fee_per_gas'],
#       dtype='object')

# %%
selected_columns=['number','size','gas_limit','gas_used','timestamp','transaction_count','base_fee_per_gas']

# %%
merge_blocks_selected = merge_blocks[selected_columns]

# %%
merge_blocks_selected.head()
# Out:
#      number    size  gas_limit  gas_used   timestamp  transaction_count  \
# 0  15467493   35021   30000000   7599434  1662237222                 52
# 1  15467593   47208   29999972  12111413  1662238920                156
# 2  15467494    6705   30000000   1674394  1662237229                 20
# 3  15467793  139953   30029295  30010865  1662241702                945
# 4  15467594   65678   30000000  15036069  1662238935                151
#
#    base_fee_per_gas
# 0        9787352044
# 1        9563105534
# 2        9183752505
# 3        2970262901
# 4        9332907583

# %%
merge_blocks_selected.to_csv('merge_blocks_selected.csv')

# %%
merge_blocks_selected.to_pickle('merge_blocks_selected.pkl')
