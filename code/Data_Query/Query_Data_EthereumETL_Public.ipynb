# %% [markdown]
# <a href="https://colab.research.google.com/github/sunshineluyao/waiting-time-eip1559/blob/main/code/Data_Query/Query_Data_EthereumETL_Public.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# references:
#
# https://github.com/blockchain-etl/ethereum-etl
#
# https://github.com/Rising-Stars-by-Sunshine/EthereumETL-Instructions/blob/main/Problem_Set_1_Demo_Ethereum_Blockchain_API.ipynb
#
# https://github.com/sunshineluyao/waiting-time-eip1559/blob/main/code/Data_Query/Query_Data_MemopoolGuru_Public.ipynb

# %% [markdown]
# # Part I: Set up

# %%
# install ethereum-etl and pandas
# !python -m pip install ethereum-etl pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 336 kB 11.7 MB/s
# ...
#      |████████████████████████████████| 501 kB 8.5 MB/s
# ...
#      |████████████████████████████████| 97 kB 3.7 MB/s
# ...
#      |████████████████████████████████| 44 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 52.6 MB/s
# ...
#      |████████████████████████████████| 45 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 20.4 MB/s
# ...
#      |████████████████████████████████| 82 kB 263 kB/s
# ...
#      |████████████████████████████████| 102 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 101 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 241 kB 54.6 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 53.5 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 36.4 MB/s
# ...

# %%
# mount google drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# print the current directory
# !pwd
# Out:
# /content

# %%
#@title path
#create a project folder and identify the path
path = "/content/drive/MyDrive/waitingtime" #@param {type:"string"}

# %%
#go to your project folder 
# %cd /content/drive/MyDrive/waitingtime
# Out:
# /content/drive/MyDrive/waitingtime

# %%
# print the current directory again to make sure that you are in the project folder
# !pwd
# Out:
# /content/drive/MyDrive/waitingtime

# %% [markdown]
# # Part II: Query Data and Export CSV

# %%
# import libraries to print data frame
import pandas as pd
# set to print the maximum numbers of rows
pd.set_option('display.max_rows', None)

# %%
#@title import using QuickNode
QuickNode_end_points_URL = "https://indulgent-cold-energy.discover.quiknode.pro/API_KEY" #@param {type:"string"}

# %% [markdown]
# ## 2.1. Query Block Data before and After the Merge

# %%
# !ethereumetl export_blocks_and_transactions --start-block 15467393 --end-block 15607393 --blocks-output blocks_merge.csv --provider-uri https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
# Out:
# Streaming output truncated to the last 5000 lines.
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/providers/rpc.py", line 36, in make_batch_request
#     raw_response = make_post_request(
#   File "/usr/local/lib/python3.8/dist-packages/web3/_utils/request.py", line 113, in make_post_request
#     response.raise_for_status()
#   File "/usr/local/lib/python3.8/dist-packages/requests/models.py", line 941, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 429 Client Error: Too Many Requests for url: https://soft-distinguished-daylight.quiknode.pro/cdf938a5284c0204abdfb8fbf8f0c2ca2f710f10/
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/ethereumetl/executors/batch_work_executor.py", line 104, in execute_with_retries
#     return func(*args)
# ...

# %%
import pandas as pd
merge_blocks = pd.read_csv('./blocks_merge.csv')
display(merge_blocks.head(10))
# Out:
#      number                                               hash  \
# 0  13084779  0xcfb96a34307b892f8d5733c968a507cde8e391e498d3...
# 1  13084979  0xcc562d78682caa2ecd823d80e0dc85cabb2976f6dfd3...
# 2  13084879  0xe34294fc049ad01526f015c1e170b66e02cad10d64f1...
# 3  13084780  0xe6b48d9b02e485ebf1810755499384e2ce1345da588d...
# 4  13084679  0xddf789f89afd4b8aea8acf804947af80fe319c7d7ced...
# 5  13084980  0x60e1835700ce6db4bb429c22c4207d6d5c5ec4e552ff...
# 6  13084880  0x6729897cb800cd5692456eddf3c505ecb5b5ced755ea...
# 7  13084781  0x18a36a42ff075df08cdfe218c494982135502fe5451d...
# 8  13084680  0x2e230424a2078ee1030af1d2b6525a50a274c826dd6d...
# 9  13084881  0x262cddd2379708341a57ba99e3f2d138fd14dd1e5ba6...
#
#                                          parent_hash               nonce  \
# 0  0xacc0b4fae677b23944dd98a1f74de27b4d355a3f279f...  0x4c116198fec4aca2
# 1  0xefcad9d77056d12128bfed4a4dc526b03b89ea4957b1...  0x7ccc4da6593f5404
# ...

# %%
merge_blocks.columns
# Out:
# Index(['number', 'hash', 'parent_hash', 'nonce', 'sha3_uncles', 'logs_bloom',
#        'transactions_root', 'state_root', 'receipts_root', 'miner',
#        'difficulty', 'total_difficulty', 'size', 'extra_data', 'gas_limit',
#        'gas_used', 'timestamp', 'transaction_count', 'base_fee_per_gas'],
#       dtype='object')

# %%
selected_columns=['number','size','gas_limit','gas_used','timestamp','transaction_count','base_fee_per_gas']

# %%
merge_blocks_selected = merge_blocks[selected_columns]

# %%
merge_blocks_selected.head()
# Out:
#      number    size  gas_limit  gas_used   timestamp  transaction_count  \
# 0  13084779   20992   30092464   3535470  1629764453                 30
# 1  13084979  127923   30151754  22525662  1629767096                292
# 2  13084879   57169   30058619  11581594  1629765668                115
# 3  13084780   21450   30121850  30112570  1629764455                 88
# 4  13084679   10652   30029181   2292403  1629763199                 25
#
#    base_fee_per_gas
# 0       49335425129
# 1       62234853088
# 2       50050964634
# 3       44617563401
# 4       54817122710

# %%
merge_blocks.sort_values(by='number', ascending=False)
# Out:
#        number                                               hash  \
# 975  13085723  0xdbe7a2ea3485bf014e055540431f7307ef6f831b073d...
# 974  13085722  0x0632e9645c21feb420a0e441ee7df3aada0252e24ce4...
# 973  13085721  0x60b03475cfb09966c48fb7e6327f30809659fe898ccb...
# 972  13085720  0x5aeb762147d08358eaf6ec511736d04cd5a12ef6dc1e...
# 971  13085719  0x70b278ed7c387861a1a79995fbeb1a92ddc91fba1955...
# ..        ...                                                ...
# 22   13084683  0x03496171eebafa1354602bab9f2fc7252513ce94f92b...
# 18   13084682  0x23d26ca646012c86aa45cbca009cefd6363787270707...
# 12   13084681  0x4d5aaa472567411ef7d6282b7d3b3231c49b58e92eae...
# 8    13084680  0x2e230424a2078ee1030af1d2b6525a50a274c826dd6d...
# 4    13084679  0xddf789f89afd4b8aea8acf804947af80fe319c7d7ced...
#
#                                            parent_hash               nonce  \
# 975  0x0632e9645c21feb420a0e441ee7df3aada0252e24ce4...  0xb7e4a3b29bbfb4b4
# ...

# %%
merge_blocks_selected.to_csv('merge_blocks_selected.csv')

# %%
merge_blocks_selected.to_pickle('merge_blocks_selected.pkl')

# %% [markdown]
# ## 2.2 Query Ethereum Blockchain Data During the Three NFT drops

# %%
# !ethereumetl export_blocks_and_transactions --start-block 13084679 --end-block 13220489 --blocks-output blocks_NFT.csv --provider-uri https://indulgent-cold-energy.discover.quiknode.pro/API_KEY

# %%
import pandas as pd
NFT_blocks = pd.read_csv('./blocks_NFT.csv')
display(NFT_blocks.head(10))
# Out:
#      number                                               hash  \
# 0  13084879  0xe34294fc049ad01526f015c1e170b66e02cad10d64f1...
# 1  13084679  0xddf789f89afd4b8aea8acf804947af80fe319c7d7ced...
# 2  13084880  0x6729897cb800cd5692456eddf3c505ecb5b5ced755ea...
# 3  13084979  0xcc562d78682caa2ecd823d80e0dc85cabb2976f6dfd3...
# 4  13085079  0x48396ba1248be92c04a6b069c4293ea11a32c08d8c4f...
# 5  13084779  0xcfb96a34307b892f8d5733c968a507cde8e391e498d3...
# 6  13084881  0x262cddd2379708341a57ba99e3f2d138fd14dd1e5ba6...
# 7  13084680  0x2e230424a2078ee1030af1d2b6525a50a274c826dd6d...
# 8  13084980  0x60e1835700ce6db4bb429c22c4207d6d5c5ec4e552ff...
# 9  13084981  0x3b38d336bca83c598f03b77c33e8c62c15b903133936...
#
#                                          parent_hash               nonce  \
# 0  0xd71f2eae93708768a7c112296f3598590730e32720ed...  0x747e0c6d08baaacc
# 1  0x998df96f8c8daa5f58ce6b00cbd281405d8e86f6854d...  0x8b40a70000443626
# ...

# %%
NFT_blocks=NFT_blocks.sort_values(by='number', ascending=True)
NFT_blocks
# Out:
#           number                                               hash  \
# 1       13084679  0xddf789f89afd4b8aea8acf804947af80fe319c7d7ced...
# 7       13084680  0x2e230424a2078ee1030af1d2b6525a50a274c826dd6d...
# 15      13084681  0x4d5aaa472567411ef7d6282b7d3b3231c49b58e92eae...
# 20      13084682  0x23d26ca646012c86aa45cbca009cefd6363787270707...
# 25      13084683  0x03496171eebafa1354602bab9f2fc7252513ce94f92b...
# ...          ...                                                ...
# 135805  13220485  0x4ac26908cf478cb24219af8f107268c7bfd3a06cb3d4...
# 135807  13220486  0x2001408279a05d5cefa3e8485f744ec9689f50741ddf...
# 135806  13220487  0x03fe11b53f6977bc124629e6417cefe4e1f82bf6df9b...
# 135810  13220488  0x4cab33f87b0aa8566b88f5e89af970588ec7b2556daa...
# 135809  13220489  0x8adec1c5c62731c98187f519eb4b8e02bbfb53b35641...
#
#                                               parent_hash               nonce  \
# ...

# %%
selected_columns=['number','size','gas_limit','gas_used','timestamp','transaction_count','base_fee_per_gas']
NFT_blocks_selected = NFT_blocks[selected_columns]
NFT_blocks_selected
# Out:
#           number    size  gas_limit  gas_used   timestamp  transaction_count  \
# 1       13084679   10652   30029181   2292403  1629763199                 25
# 7       13084680   18762   30058505   4458662  1629763201                 56
# 15      13084681   89606   30029152  30023592  1629763205                246
# 20      13084682  166011   30000000  21704672  1629763231                210
# 25      13084683   20832   30029295   2373575  1629763234                 22
# ...          ...     ...        ...       ...         ...                ...
# 135805  13220485   39837   30000000   5594670  1631577563                 66
# 135807  13220486  126266   30000000  29989912  1631577564                354
# 135806  13220487   21379   30000000   5950800  1631577575                 29
# 135810  13220488  138288   30029295  30020471  1631577576                432
# 135809  13220489   88497   30000000  19030603  1631577619                200
#
#         base_fee_per_gas
# ...

# %%
NFT_blocks_selected.to_csv('NFT_blocks_selected.csv')
NFT_blocks_selected.to_pickle('NFT_blocks_selected.pkl')
